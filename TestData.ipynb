# %%
from astropy.io import fits
from astropy.visualization import astropy_mpl_style

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import gridspec

# %%
#datafile = fits.open('FRB191001_GMOSspec.fits')
#hdr2 = datafile[1].header
#image_data = datafile[1].data

#ncol = hdr2['NAXIS1']   #Number of columns
#nrow = hdr2['NAXIS2']   #Number of rows

# %%
datafile = fits.open('HG_191001_FORS2_I_ac.fits')
hdr = datafile[0].header
image_data = datafile[0].data

ncol = hdr['NAXIS1']   #Number of columns
nrow = hdr['NAXIS2']   #Number of rows

# %%
hdr
# Out:
# SIMPLE  =                    T
# BITPIX  =                  -64
# NAXIS   =                    2
# NAXIS1  =                 1565
# NAXIS2  =                 1584
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# CTYPE1  = 'RA---TAN'           / Type of co-ordinate on axis 1
# CTYPE2  = 'DEC--TAN'           / Type of co-ordinate on axis 2
# CRVAL1  =        323.352840089 / Value at ref. pixel on axis 1
# CRVAL2  =        -54.748185479 / Value at ref. pixel on axis 2
# CRPIX1  =           778.532413 / Reference pixel on axis 1
# CRPIX2  =           792.477979 / Reference pixel on axis 2
# CDELT1  =  -7.0023952947774812E-5 / Pixel size
# CDELT2  =  7.01100488062816933E-5 / Pixel size
# CROTA2  = 0.0876229835120551359 / Axis rotation
# AIRMASS =               1.1592
# FILTER  = 'I_BESS  '
# ...

# %%
fig, ax = plt.subplots(figsize=(12,8))
im = ax.imshow(image_data, interpolation='nearest', cmap='ocean', aspect = 'auto', vmin=0, vmax=225)

# %%
datafile = fits.open('FRB191001_GMOSspec.fits')
hdr = datafile[0].header
hdr2 = datafile[1].header
image_data = datafile[1].data

ncol = hdr2['NAXIS1']   #Number of columns
nrow = hdr2['NAXIS2']   #Number of rows

# %%
hdr2
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   12 / length of dimension 1
# NAXIS2  =                 3240 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                    3 / number of table fields
# TTYPE1  = 'WAVELENGTH'
# TFORM1  = 'E       '
# TTYPE2  = 'FLUX    '
# TFORM2  = 'E       '
# TTYPE3  = 'ERROR   '
# TFORM3  = 'E       '

# %%
image_data
# Out:
# FITS_rec([(4985.5254, 17.20186 , 2.7338617 ),
#           (4987.179 , 17.823917, 3.1241975 ),
#           (4988.6294, 13.936277, 3.020245  ), ...,
#           (9886.709 ,  6.280739, 0.45187184),
#           (9887.847 ,  9.16356 , 0.61834294),
#           (9891.677 , 18.712215, 1.1194354 )],
#          dtype=(numpy.record, [('WAVELENGTH', '>f4'), ('FLUX', '>f4'), ('ERROR', '>f4')]))

# %%
# Load in spectrum
hdul = fits.open('FRB191001_GMOSspec.fits')
hdr = hdul[0].header
dat = hdul[1].data
wl = dat['WAVELENGTH'] # in units AA
flux = dat['FLUX'] # in units of x10^-17 erg/s/cm^2/Å
sig = dat['ERROR'] # same

# %%
plt.plot(wl,flux,'.')
#plt.xlim(6600,6800)
#plt.xlim(8050,8150);

# %%
hdul.info()
# Out:
# Filename: FRB191001_GMOSspec.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1                1 BinTableHDU     14   3240R x 3C   ['E', 'E', 'E']

# %% [markdown]
# HCUL = Header Data Unit List
#
# An HDU is the highest level component of the FITS file structure, consisting of a header and (typically) a data array or table
#
# As mentioned earlier, each element of an HDUList is an HDU object with .header and .data attributes, which can be used to access the header and data portions of the HDU.
